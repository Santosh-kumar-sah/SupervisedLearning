# %% [markdown]
# #### Cost Function- A cost function is an important parameter that determines how well a machine learning model performs for a given dataset.

# %% [markdown]
# #### (1)Regression cost  (2) Classification cost Function

# %% [markdown]
# ### regression cost function
# ### Mean Squared Error (MSE)
# ### Mean Absolute Error (MAE)
# ### Mean Square Root Error (MSRE)

# %% [markdown]
# ####  Regularization Techniques(form of regression that penalizes large coefficients to prevent overfitting)
# ##### 1. L1 Regularization (Lasso Regression)-Used in Feature Selection using Shrinkage method also referred as penalized regression method;
# ##### It shifts towards zero
# ##### Cost Function = Loss + Lembda * Sigam||w|| (Loss = Sum of Sqaured residual, Lembda = penalty, w = slope of the curve)
#
#
# ##### 2. L2 Regularization (Ridge Regression)- Reduce model complexity and help prevent overfitting. its working value of coefficients is almost equalt to Zero.
# ##### Cost function = Loss + Lembda* Sigma||w||2 (2 is power of w )
