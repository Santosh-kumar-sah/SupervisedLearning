# %% [markdown]
# ##### Decision Tree (Regression)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("employee.csv")
print(dataset.head(3))
# Out:
#    Age  Experience  Salary
# 0   41          12   80561
# 1   24          18  110848
# 2   25           7   42219

# %%
dataset.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(dataset)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["Experience"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_test,y_test)*100
# Out:
# 97.70378874856488

# %%
dt.score(x_train,y_train)*100
# Out:
# 100.0

# %% [markdown]
# ##### not overfitting as score of test and train is almost same

# %%
plot_tree(dt)
plt.show()
# Out:
# [Text(0.53125, 0.9166666666666666, 'x[1] <= 17.0\nsquared_error = 80.637\nsamples = 40\nvalue = 16.25'),
#  Text(0.2727272727272727, 0.75, 'x[1] <= 9.0\nsquared_error = 16.845\nsamples = 22\nvalue = 9.136'),
#  Text(0.40198863636363635, 0.8333333333333333, 'True  '),
#  Text(0.125, 0.5833333333333334, 'x[1] <= 4.5\nsquared_error = 4.96\nsamples = 10\nvalue = 5.2'),
#  Text(0.045454545454545456, 0.4166666666666667, 'x[1] <= 2.5\nsquared_error = 0.688\nsamples = 4\nvalue = 2.75'),
#  Text(0.022727272727272728, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.06818181818181818, 0.25, 'x[1] <= 3.5\nsquared_error = 0.25\nsamples = 2\nvalue = 3.5'),
#  Text(0.045454545454545456, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.09090909090909091, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.20454545454545456, 0.4166666666666667, 'x[0] <= 43.5\nsquared_error = 1.139\nsamples = 6\nvalue = 6.833'),
#  Text(0.1590909090909091, 0.25, 'x[1] <= 7.5\nsquared_error = 0.25\nsamples = 4\nvalue = 7.5'),
#  Text(0.13636363636363635, 0.08333333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.18181818181818182, 0.08333333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 8.0'),
#  Text(0.25, 0.25, 'x[1] <= 5.5\nsquared_error = 0.25\nsamples = 2\nvalue = 5.5'),
#  Text(0.22727272727272727, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.2727272727272727, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.42045454545454547, 0.5833333333333334, 'x[1] <= 12.5\nsquared_error = 3.076\nsamples = 12\nvalue = 12.417'),
#  Text(0.36363636363636365, 0.4166666666666667, 'x[1] <= 11.5\nsquared_error = 0.408\nsamples = 7\nvalue = 11.143'),
#  Text(0.3409090909090909, 0.25, 'x[1] <= 10.5\nsquared_error = 0.16\nsamples = 5\nvalue = 10.8'),
#  Text(0.3181818181818182, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(0.36363636363636365, 0.08333333333333333, 'squared_error = 0.0\nsamples = 4\nvalue = 11.0'),
#  Text(0.38636363636363635, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 12.0'),
#  Text(0.4772727272727273, 0.4166666666666667, 'x[1] <= 14.5\nsquared_error = 1.36\nsamples = 5\nvalue = 14.2'),
#  Text(0.4318181818181818, 0.25, 'x[1] <= 13.5\nsquared_error = 0.222\nsamples = 3\nvalue = 13.333'),
#  Text(0.4090909090909091, 0.08333333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 13.0'),
#  Text(0.45454545454545453, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.5227272727272727, 0.25, 'x[1] <= 15.5\nsquared_error = 0.25\nsamples = 2\nvalue = 15.5'),
#  Text(0.5, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 15.0'),
#  Text(0.5454545454545454, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 16.0'),
#  Text(0.7897727272727273, 0.75, 'x[1] <= 25.0\nsquared_error = 21.164\nsamples = 18\nvalue = 24.944'),
#  Text(0.6605113636363636, 0.8333333333333333, '  False'),
#  Text(0.6818181818181818, 0.5833333333333334, 'x[1] <= 22.0\nsquared_error = 4.21\nsamples = 10\nvalue = 21.3'),
#  Text(0.6363636363636364, 0.4166666666666667, 'x[1] <= 20.0\nsquared_error = 1.472\nsamples = 6\nvalue = 19.833'),
#  Text(0.6136363636363636, 0.25, 'x[0] <= 34.5\nsquared_error = 0.222\nsamples = 3\nvalue = 18.667'),
#  Text(0.5909090909090909, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.6363636363636364, 0.08333333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 19.0'),
#  Text(0.6590909090909091, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 21.0'),
#  Text(0.7272727272727273, 0.4166666666666667, 'x[1] <= 23.5\nsquared_error = 0.25\nsamples = 4\nvalue = 23.5'),
#  Text(0.7045454545454546, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 23.0'),
#  Text(0.75, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 24.0'),
#  Text(0.8977272727272727, 0.5833333333333334, 'x[1] <= 29.5\nsquared_error = 5.0\nsamples = 8\nvalue = 29.5'),
#  Text(0.8409090909090909, 0.4166666666666667, 'x[0] <= 41.0\nsquared_error = 1.25\nsamples = 4\nvalue = 27.5'),
#  Text(0.7954545454545454, 0.25, 'x[1] <= 26.5\nsquared_error = 0.25\nsamples = 2\nvalue = 26.5'),
#  Text(0.7727272727272727, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.8181818181818182, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.8863636363636364, 0.25, 'x[0] <= 53.5\nsquared_error = 0.25\nsamples = 2\nvalue = 28.5'),
#  Text(0.8636363636363636, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 29.0'),
#  Text(0.9090909090909091, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 28.0'),
#  Text(0.9545454545454546, 0.4166666666666667, 'x[1] <= 31.0\nsquared_error = 0.75\nsamples = 4\nvalue = 31.5'),
#  Text(0.9318181818181818, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.9772727272727273, 0.25, 'squared_error = 0.0\nsamples = 3\nvalue = 32.0')]
