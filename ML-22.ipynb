# %% [markdown]
# #### Classificaton - is used to identify the category of new observations on the basis of training data.
#
# #### Such as Yes or No, 0 or 1, Spam or not Spam, cat or dog

# %% [markdown]
# #### Types:
# ##### (1)Binary Classifier - Has two possible outcomes (Spam or not Spam, cat or dog)
# ##### (2) Has more than two outcomes(types of crops,types of music)
#
# #### Tpes of Algo:
# #### (1)Non-Linear Models:-
# ##### (i)K-Nearest Neighbours
# ##### (ii)SVM
# ##### (iii)Naive Bayes
# ##### (iv)Decision Tree Classification
# ##### (v)Random Forest Classification
#
# #### (2)Linear Modekls
# ##### (i)Logistic Regression
# ##### (ii)Support Vector Machines
#
# #### But main is two types of classification:- (1)Naive Bayes (2) logistic (Rest are also comes in Regression)
