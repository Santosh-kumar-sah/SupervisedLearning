# %% [markdown]
# #### Polynomial Regression
# #### dependent var(y) and independent variable(x) as nth degree polynomial
# #### Y = b0 +b1x1 +b2x1sqaure+b3x1cube+.....bnx1n

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('level_vs_salary.csv')

# %%
dataset.head(3)
# Out:
#    Level  Salary
# 0      7   37610
# 1      4   20042
# 2      8   41363

# %%
dataset.corr()
# Out:
#            Level    Salary
# Level   1.000000  0.991069
# Salary  0.991069  1.000000

# %%
plt.scatter(dataset["Level"], dataset["Salary"], color='red')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %%
x = dataset[['Level']]
y = dataset['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=4)
x_train_poly = pf.fit_transform(x_train)
x_test_poly = pf.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test_poly, y_test)*100
# Out:
# c:\Users\sures\OneDrive\Desktop\python\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 lr.score(x_test_poly, y_test)*100
#
# File c:\Users\sures\OneDrive\Desktop\python\.venv\Lib\site-packages\sklearn\base.py:638, in RegressorMixin.score(self, X, y, sample_weight)
#     596 """Return :ref:`coefficient of determination <r2_score>` on test data.
#     597
#     598 The coefficient of determination, :math:`R^2`, is defined as
#    (...)    633 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     634 """
#     636 from .metrics import r2_score
# --> 638 y_pred = self.predict(X)
#     639 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# ...

# %%
lr.coef_
# Out:
# array([4930.12009725])

# %%
lr.intercept_
# Out:
# np.float64(405.65338046435863)

# %%
# y =490.0*4 + 24400.0*2 + 36100.0*1 + 405.65

# %%
# prd = lr.predict(x)

# %%
plt.scatter(dataset.Level, dataset.Salary, color='red')
plt.xlabel('Level')
plt.ylabel('Salary')    
plt.plot(dataset.Level, prd, color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 plt.xlabel('Level')
#       3 plt.ylabel('Salary')
# ----> 4 plt.plot(dataset.Level, prd, color='blue')
#       5 plt.show()
#
# NameError: name 'prd' is not defined

# %%
# when deployig the model
test =pf.transform([[45]])
test
# Out:
# c:\Users\sures\OneDrive\Desktop\python\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.000000e+00, 4.500000e+01, 2.025000e+03, 9.112500e+04,
#         4.100625e+06]])

# %%
lr.predict(x_test_poly)
# Out:
# c:\Users\sures\OneDrive\Desktop\python\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 lr.predict(x_test_poly)
#
# File c:\Users\sures\OneDrive\Desktop\python\.venv\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File c:\Users\sures\OneDrive\Desktop\python\.venv\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# ...
